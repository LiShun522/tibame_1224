# %% [markdown]
# # Overview of seaborn plotting functions

# %% [markdown]
# 主要繪圖功能分成三大類
# # 1. 分布圖        2. 直方圖(單一值)             3. 類別型圖

# %% [markdown]
# ![image.png](attachment:cf7b1011-dc6e-4b52-b9ca-f52dfa2c6f1f.png)

# %% [markdown]
# # Visualizing statistical relationships
# * https://seaborn.pydata.org/tutorial/relational.html
#
# 統計分析是了解資料集中的變數如何相互關聯以及這些關係如何依賴其他變數的過程。視覺化可以成為此過程的核心組成部分，因為當資料正確視覺化時，人類視覺系統可以看到表明關係的趨勢和模式。最常用的是 [relplot()](https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot)，用於使用兩種常見方法來視覺化統計關係：散點圖(scatter plots)和線圖(line plots)。
# # 散佈圖()預設
# * [scatterplot()](https://seaborn.pydata.org/generated/seaborn.scatterplot.html#seaborn.scatterplot) (with kind="scatter"; the default)
# # 線圖
# * [lineplot()](https://seaborn.pydata.org/generated/seaborn.lineplot.html#seaborn.lineplot) (with kind="line")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
#練習題
#單純使用Matplotlib來實現上圖
# x=["total_bill"]
# y=["tip"]
# plt.plot(x, np.tan(x), '-')
plt.scatter(tips['total_bill'], tips['tip'], marker='.')
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.show()

# %%
#練習題
#繪出散佈圖 x為bill_length_mm, y為bill_depth_mm
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.relplot(data=penguins, x="bill_length_mm", y="bill_depth_mm") # 可以不用 data=

# %% [markdown]
# 雖然這些點是以二維繪製的，但可以透過根據第三個變數對點進行著色來將另一個維度添加到圖中。

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %%
iris = sns.load_dataset("iris")
iris.head()
sns.relplot(iris, x = "sepal_length", y = "sepal_width", hue = "species")

# %%
#練習題
#單純使用Matplotlib來實現上圖

# %%
#練習題
#繪出散佈圖 x為bill_length_mm, y為bill_depth_mm, 分類為species
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# 為了強調類別之間的差異並提高可訪問性，您可以為每個類別使用不同的標記樣式：

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="smoker"
)

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
penguins = sns.load_dataset("penguins")
penguins.head()
sns.relplot(penguins, x = "bill_length_mm", y = "bill_depth_mm", hue = "species", style = "island"),
sns.relplot(penguins, x = "flipper_length_mm", y = "body_mass_g", hue = "species", style = "species") # 綠色可容易被分出，但另外兩樣就要用別的方式

# %% [markdown]
# 也可以透過獨立更改每個點的色調和樣式來表示四個變數。但這應該小心地進行，因為眼睛對形狀的敏感度遠低於對顏色的敏感度：

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="time",
)

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
penguins = sns.load_dataset("penguins")
penguins.head()

# %% [markdown]
# 在上面的範例中，色調語義(hue)是分類的，因此應用了預設的定性調色板。如果色調語義是數字（具體來說，如果它可以轉換為浮動），則預設顏色切換到順序調色板：

# %%
# 連續性的他會自動幫你分深淺
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size",
)

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
penguins = sns.load_dataset("penguins")
penguins.head()
sns.relplot(penguins, x = "bill_length_mm", y = "bill_depth_mm", hue = "bill_length_mm"),
sns.relplot(penguins, x = "flipper_length_mm", y = "body_mass_g", hue = "flipper_length_mm"),
# Out:
# (<seaborn.axisgrid.FacetGrid at 0x25fa1a55b10>,)

# %%
# 套用 Color Map
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size",
    palette="viridis"
)

# %% [markdown]
# color maps 可以參考 https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
penguins = sns.load_dataset("penguins")
penguins.head()

# %% [markdown]
# 第三種視覺化鑑別資料的方法是使用大小：

# %%
sns.relplot(data=tips, x="total_bill", y="tip", size="size") # 非數值型資料不適用

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
penguins = sns.load_dataset("penguins")
penguins.head()
sns.relplot(penguins, x = "bill_length_mm", y = "bill_depth_mm", size = "body_mass_g")

# %%
# 指定點的大小範圍
sns.relplot(
    data=tips, x="total_bill", y="tip",
    size="size", sizes=(15, 200)
)

# %% [markdown]
# # 使用線圖來顯示連續性 (不適合散佈圖)
# 對於某些資料集，您可能想要了解一個變數隨時間的變化，或類似的連續變數。在這種情況下，畫線圖是一個不錯的選擇。在seaborn中，這可以透過lineplot()函數來完成，可以直接使用，也可以透過設定kind="line"來使用relplot()來完成：

# %%
dowjones = sns.load_dataset("dowjones")
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=dowjones, x="Date", y="Price", kind="line"), # 預，所以要加上 kind= 
# 等同
sns.lineplot(data=dowjones, x="Date", y="Price")
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
# 如果不使用線圖會變成這樣
sns.relplot(data=dowjones, x="Date", y="Price")

# %% [markdown]
# # 聚合和表示不確定性
# 更複雜的資料集將對 x 變數的相同值進行多次測量。 seaborn 中的預設行為是透過繪製平均值和圍繞平均值的 95% 置信區間來聚合每個 x 值的多個測量值：

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
taxis = sns.load_dataset("taxis")
taxis.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
sns.relplot(taxis, x="passengers", y="tip", kind="line") # 乘客、小費

# %%
# 如果不使用線圖會變成這樣
sns.relplot(data=fmri, x="timepoint", y="signal")

# %% [markdown]
# 置信區間是使用自舉法計算的，對於較大的資料集來說，這可能非常耗時。因此可以禁用它們：

# %%
# 要不要把信任區間畫出來
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar=None,
)

# %% [markdown]
# 另一個不錯的選擇，特別是對於較大的數據，是透過繪製標準差而不是置信區間來表示每個時間點的分佈分佈：

# %%
# 將信任區間使用標準差
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar="sd",
)

# %%
# SS S M L XL XXL XXXL
# M ~ XL 85%人
# S ~ XXL 95% 
# 燈泡保固
# 平均3000小時
# 在平均值往標準差出去 3~5%

# %% [markdown]
# 預設情況下，向線圖新增樣式語意會變更線中的破折號模式：

# %%
# 實線 根 虛線
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal",
    hue="region", style="event",
)

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
taxis = sns.load_dataset("taxis")
taxis.head()

# %% [markdown]
# 但是您可以透過每次觀察時使用的標記來識別子集，可以與破折號一起使用，也可以代替它們：

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="region", style="event",
    dashes=False, markers=True,
)

# %% [markdown]
# # Showing multiple relationships with facets
# 雖然函數可以同時顯示多個語義變量(資料欄位)，但這樣做並不總是有效。但是，當您確實想了解兩個變數之間的關係如何依賴多個其他變數時該怎麼辦？
#
# 最好的方法可能是製作多個圖。因為 relplot() 是基於 FacetGrid，所以這很容易做到。為了顯示附加變數的影響，不要將其指派給圖中的語義角色之一，而是使用它來「分面」視覺化。這意味著您創建多個軸並在每個軸上繪製資料子集：

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 在一張圖中分別使用顏色跟點樣式來代表smoker與time
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="time",
)

# %% [markdown]
# ↑ 上面這張圖雖然分別使用顏色跟樣式來代表不同的資料欄位，但是看起來還是很雜亂<BR>
# ↓ 比較合適的方法是將 time 這個欄位分成兩張不同的圖來並列顯示

# %%
# 增加另一個欄位 EX 中餐 、晚餐 用時間切，因為只有兩個值
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", col="time",
)

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="species", col="island",
),

# style= "island"，但就不明顯
sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="species", style="island",
)

# %% [markdown]
# 您也可以透過這種方式顯示兩個變數的影響：一種透過在列上分面，一種透過在行上分面。當您開始在網格上新增更多變數時，您可能需要減少圖形大小。請記住，FacetGrid 的大小由每個面的高度和縱橫比參數化：

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", col="time", row="sex"
)

# %%
#練習題
#使用下面資料，仿造上圖來繪圖
penguins = sns.load_dataset("penguins")
penguins.head()
sns.relplot(
    penguins,
    x="bill_length_mm", y="body_mass_g", hue="species", col="island", row = "sex"
),
# Out:
# (<seaborn.axisgrid.FacetGrid at 0x25fa1f5a450>,)

# %%
# 另一個範例
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="subject",
    col="region", row="event", height=3,
    estimator=None
)

# %% [markdown]
# 當您想要檢查變數的多個層級的影響時，最好在列上對該變數進行分面，然後將分面「包裝(wrap)」到行中：

# %%
# 不使用col_wrap時的效果
sns.relplot(
    data=fmri.query("region == 'frontal'"), kind="line",
    x="timepoint", y="signal", hue="event", style="event",
    col="subject", #col_wrap=5, # 強制換行的參數
    height=3, aspect=.75, linewidth=2.5,
)

# %%
sns.relplot(
    data=fmri.query("region == 'frontal'"), kind="line",
    x="timepoint", y="signal", hue="event", style="event",
    col="subject", col_wrap=5, # 強制換行的參數
    height=3, aspect=.75, linewidth=2.5,
)
